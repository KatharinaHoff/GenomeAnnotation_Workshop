# %% [markdown]
# # Annotating the Chromsome 4 of *Babesia duncani*
#
# Originally, we had intended to provide an exercise for annotating a complete small genome. However, the computational resources available on AWS for this workshop do not permit completion of the task within one afternoon. Therefore, we provide the annotation of Chromosome 4 of *Babesia duncani* as a hands-on exercise for practicing your skills.
#
#
# *Babesia duncani* is a protozoan parasite that infects red blood cells in humans. It is primarily transmitted through tick bites. *Babesia duncani* is known to cause a malaria-like illness called babesiosis, which can lead to symptoms such as fever, fatigue, muscle aches, and anemia. The [genome](https://www.ncbi.nlm.nih.gov/data-hub/taxonomy/323732/) has a size of 10.4 Mb. We selected Chromsome 4 from this genome, which is about 1 Mb in size.
#
# **Warning:* None of the self-training genome annotation tools (BRAKER1, BRAKER2, BRAKER3, GALBA) are particularly suitable for annotating partial genomes. We strongly advise against doing this in practice. Please always use genomes as complete as possible. The only reason why we resort to a chunk of a genome, here, are limited computational and time resources during this workshop.
#
# Your task is today to annotate this partial genome with several methods: BRAKER3, BRAKER2, BRAKER1, GALBA, and possibly TSEBRA combinations of the beforementioned, and (a) produce a high quality annotation in a fully automated way, and (b) find out which method produces best results.
#
#
# ## Data
#
# The genome is available at [/home/genomics/workshop_material/genome_annotation/genome/genome.fa](/home/genomics/workshop_material/genome_annotation/genome/genome.fa). We will be using the repeat masking provided by NCBI.
#
# We downloaded and aligned the library SRR18907291 from [Sequence Read Archive](https://www.ncbi.nlm.nih.gov/sra). (Paired-end Illumina library, Hisat2 aligner, converted and sorted with Samtools, selected aligned reads with Samtools to reduce bam file size.) It is not feasible that we process this data set during the workhop. We provide the file [/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam](/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam).
#
# In terms of OrthoDB taxonomy, the Alveolata partition is "the closest" for this species, available at [/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa](/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa). This is a rather "small" partition, and a priori, we do not know whether it will be sufficient for running BRAKER3 or BRAKER2 if used as the only protein input. We recommend combining it with proteins of other *Babesia* species (see below).
#
# Proteomes of other *Babesia* species were downloaded from NCBI, they were concatenated, and the fasta headers have been replaced by short, simple, and unique headers. The resulting file to be used with GALBA is available at [/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa](/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa).
#
# ## What to expect?
#
# This genome has no complete reference annotation, yet. Looking at other *Babesia* genomes, we exepect 3,000 to 5,000 proteins in the full genome. Chromosome 4 makes up only 10% of the total genome, i.e. we possibly expect 300 to 500 proteins to be predicted in this genome part.
#
# We applied BUSCO to the genome as follows:
#
# ```
# busco -m genome -i genome.fa -o busco_genome -l alveolata_odb10
# ```
#
# and obtained this output:
#
# ```
# C:17.5%[S:17.5%,D:0.0%],F:1.2%,M:81.3%,n:171
# ```
#
# The BUSCO core gene set for Alveolata is relatively small (only 171 genes). However, we expect similar sensitivity scores with a well-performing tool for structural genome annotation.
#
# ## Group assignment
#
# Runtime is a serious issue. Therefore, you are split into 4 different groups, and you will at first only complete the task of the group that you were assigned to. Execute the following code cell once to see which group are in:

# %%
import random
print("You are in group ", random.randint(1,5))

# %% [markdown]
# For all tasks, there is a possibility of failure. Should your task fail (e.g. because not sufficient evidence was provided), pick a new group by re-executing the above code cell.
#
# ## Questions to all groups (with respect to the assigned task)
#
# 1. After executing the annotation task assigned to you, apply BUSCO to estimate proteome completentess (use [/home/genomics/workshop_material/genome_annotation/alveolata_odb10](/home/genomics/workshop_material/genome_annotation/alveolata_odb10)). What are the BUSCO scores?
#
# 2. How many genes and how many transcripts are predicted?
#
# 3. How is the mono:mult ratio?
#
# 4. What is the median number of exons per transcript?
#
# 5. What is the largest number of exons in a transcript?
#
# Fill in the results for your task(s) at our [Google Results Sheet](https://docs.google.com/spreadsheets/d/1WT3LGMrvWS-ai3xRjFLVvFMSUlLTfqMFnYISbQES99I/edit?usp=sharing) in the grey fields. If no results can be obtained, enter "NA".
#
# ## Common pitfalls
#
#    * **Warning** BRAKER or GALBA may warn you that the number of training genes is very low. In our example, we are using only a partial genome, and for today, we will ignore this warning. However, in a real-life scenario with a complete genome, you should be cautious when seeing such a warning. It's not advisable to train a gene finder with less than 200 genes. Having more than 200 training genes may or may not give good results. A large number of training genes (no warning shown) often leads to good results.
#
#    * Sometimes, a step in the pipeline may fail when processing your specific dataset. BRAKER usually reports that the most common problem is a missing or expired file called ~/.gm_key. However, during the workshop, we can assure you that the key file is not expired or missing! To find the actual reason for the failure, you can check the error file of the last command executed by BRAKER. You can find that command in the braker.log file in the working directory. Most often, the reason for the failure is missing data. In this workshop, we won't add any additional data to solve this problem as it would increase the runtime. However, in real-life scenarios, you may be able to overcome the issue by adding more RNA-Seq data or more protein data.
#
# ## Task for group 1: Apply GALBA
#
# Use the following code cell to implement the application of GALBA, and execute GALBA. Use the genome file and the proteins.fa file mentioned, above. Apply `--skipOptimize`. (Expected runtime: ~10 minutes.)

# %%
# %%script bash
# T=4 # adjust to number of threads that you booted with
#
# # delete output from a possible previous run if it exists
# if [ -d GALBA_babesia ]
# then
#     rm -rf GALBA_babesia
# fi
#
# time galba.pl --workingdir=GALBA_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \
#     --prot_seq=/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa \
#     --AUGUSTUS_BIN_PATH=/usr/bin/ --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \
#     --skipOptimize
# Out:
# # Sun May  7 12:27:55 2023: Log information is stored in file /home/katharina/git/GenomeAnnotation_Workshop2023/GALBA_babesia/GALBA.log
# #*********
# # WARNING: Number of reliable training genes is low (34). Recommended are at least 600 genes
# #*********
# #*********
# # WARNING: Number of reliable training genes is low (34). Recommended are at least 600 genes
# #*********
# real	10m51.353s
# user	11m37.444s
# sys	0m6.867s

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with
#
# source conda_init
# conda activate busco_env
#
# cd GALBA_babesia
# # create links if not already present
# if [ ! -d busco_downloads ]
# then
#     mkdir busco_downloads
#     cd busco_downloads
#     if [ ! -L alveolata_odb10 ]
#     then
#         ln -s /home/genomics/workshop_material/genome_annotation/busco/alveolata_odb10 alveolata_odb10
#     fi
# fi
#
# # delete old output if existing
# if [ -d busco_galba_babesia ]
# then
#     rm -r busco_galba_babesia
# fi
#
# # run BUSCO
# busco -m proteins -i augustus.hints.aa -o busco_galba_babesia \
#         -l alveolata_odb10 -c ${T} &> busco_galba_babesia.log
#
# # Count number of transcripts by counting FASTA headers
# echo "Counting number of protein sequences = transcripts"
# grep -c ">" augustus.hints.aa
#
# # Number of genes, and descriptive statistics
# echo "Computing some descriptive statistics for GALBA:"
# analyze_exons.py -f augustus.hints.gtf
# Out:
# Counting number of protein sequences = transcripts
# 516
# Computing some descriptive statistics for GALBA:
# Number of transcripts: 468
# Largest number of exons in all transcripts: 2
# Monoexonic transcripts: 240
# Multiexonic transcripts: 228
# Mono:Mult Ratio: 1.05
# Boxplot of number of exons per transcript:
# Min: 1
# 25%: 1
# 50%: 1
# 75%: 2
# Max: 2

# %% [markdown]
# ## Task for group 2: Apply BRAKER3
#
# Use the following code cell to implement the application of BRAKER3, and execute BRAKER3. Use the genome file, the OrthoDB Metazoa file, the proteins.fa file, and the Merged.bam file mentioned, above. Apply `--skipOptimize`. Do not apply `--gm_max_intergenic 10000`. (Expected runtime: ~10 minutes.)

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with, takes ~30 minutes with 4 threads
#
# # delete output from a possible previous run if it exists
# if [ -d BRAKER3_babesia ]
# then
#     rm -rf BRAKER3_babesia
# fi
#
# ORTHODB=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa # adjust to suitable clade
#
# # run BRAKER3
# time braker.pl --workingdir=BRAKER3_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \
#     --bam=/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam \
#     --prot_seq=${ORTHODB},/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa \
#     --AUGUSTUS_BIN_PATH=/usr/bin/ \
#     --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \
#     --skipOptimize
# Out:
# #**********************************************************************************
# #                               BRAKER CONFIGURATION
# #**********************************************************************************
# # BRAKER CALL: /opt/BRAKER/scripts/braker.pl --workingdir=BRAKER3_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa --bam=/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam --prot_seq=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa,/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa --AUGUSTUS_BIN_PATH=/usr/bin/ --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads 4 --skipOptimize
# # Sun May  7 12:45:53 2023: braker.pl version 3.0.3
# # Sun May  7 12:45:53 2023: Creating directory /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia.
# # Sun May  7 12:45:53 2023: Creating directory /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia.
# # Sun May  7 12:45:53 2023:Both protein and RNA-Seq data in input detected. BRAKER will be executed in ETP mode (BRAKER3).
# #*********
# # Sun May  7 12:45:53 2023: Configuring of BRAKER for using external tools...
# # Sun May  7 12:45:53 2023: Trying to set $AUGUSTUS_CONFIG_PATH...
# # Sun May  7 12:45:53 2023: Found environment variable $AUGUSTUS_CONFIG_PATH.
# # Sun May  7 12:45:53 2023: Checking /usr/share/augustus/config/ as potential path for $AUGUSTUS_CONFIG_PATH.
# # Sun May  7 12:45:53 2023: Success! Setting $AUGUSTUS_CONFIG_PATH to /usr/share/augustus/config/!
# # Sun May  7 12:45:53 2023: WARNING: in file /opt/BRAKER/scripts/braker.pl at line 1894
# AUGUSTUS_CONFIG_PATH/species (in this case /usr/share/augustus/config//species) is not writeable. BRAKER will try to copy the AUGUSTUS config directory to a writeable location.
# # Sun May  7 12:45:53 2023: Creating directory /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia.
# # Sun May  7 12:45:53 2023:Both protein and RNA-Seq data in input detected. BRAKER will be executed in ETP mode (BRAKER3).
# #*********
# # Sun May  7 12:45:54 2023: Log information is stored in file /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/braker.log
# #*********
# # WARNING: Detected whitespace in fasta header of file /home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa. This may later on cause problems! The pipeline will create a new file without spaces or "|" characters and a genome_header.map file to look up the old and new headers. This message will be suppressed from now on!
# #*********
# ERROR in file /opt/BRAKER/scripts/braker.pl at line 5473
# Failed to execute: /usr/bin/perl /opt/ETP/bin/gmetp.pl --cfg /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP/etp_config.yaml --workdir /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP --bam /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP/etp_data/ --cores 4 --softmask  1>/home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/errors/GeneMark-ETP.stdout 2>/home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/errors/GeneMark-ETP.stderr
# Failed to execute: /usr/bin/perl /opt/ETP/bin/gmetp.pl --cfg /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP/etp_config.yaml --workdir /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP --bam /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/GeneMark-ETP/etp_data/ --cores 4 --softmask  1>/home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/errors/GeneMark-ETP.stdout 2>/home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER3_babesia/errors/GeneMark-ETP.stderr
# The most common problem is an expired or not present file ~/.gm_key or that GeneMark-ETP didn't receive enough evidence from the input data, in this case, see errors/GeneMark-ETP.stderr!
#
# real	10m26.285s
# user	50m51.504s
# sys	1m14.129s
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('script', 'bash', '\nT=4 # adjust to number of threads that you booted with, takes ~30 minutes with 4 threads\n\n# delete output from a possible previous run if it exists\nif [ -d BRAKER3_babesia ]\nthen\n    rm -rf BRAKER3_babesia\nfi\n\nORTHODB=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa # adjust to suitable clade\n\n# run BRAKER3\ntime braker.pl --workingdir=BRAKER3_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \\\n    --bam=/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam \\\n    --prot_seq=${ORTHODB},/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa \\\n    --AUGUSTUS_BIN_PATH=/usr/bin/ \\\n    --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \\\n    --skipOptimize\n')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2430, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2428 with self.builtin_trap:
#    2429     args = (magic_arg_s, cell)
# -> 2430     result = fn(*args, **kwargs)
#    2432 # The code below prevents the output from being displayed
#    2433 # when using magics with decodator @output_can_be_silenced
#    2434 # when the last Python token in the expression is a ';'.
#    2435 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\nT=4 # adjust to number of threads that you booted with, takes ~30 minutes with 4 threads\n\n# delete output from a possible previous run if it exists\nif [ -d BRAKER3_babesia ]\nthen\n    rm -rf BRAKER3_babesia\nfi\n\nORTHODB=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa # adjust to suitable clade\n\n# run BRAKER3\ntime braker.pl --workingdir=BRAKER3_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \\\n    --bam=/home/genomics/workshop_material/genome_annotation/sra/SRR18907291.s.mapped.bam \\\n    --prot_seq=${ORTHODB},/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa \\\n    --AUGUSTUS_BIN_PATH=/usr/bin/ \\\n    --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \\\n    --skipOptimize\n'' returned non-zero exit status 1.

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with
#
# # CANNOT BE EXECUTED, BRAKER3 DIES!
#
# source conda_init
# conda activate busco_env
#
# cd BRAKER3_babesia
# # create links if not already present
# if [ ! -d busco_downloads ]
# then
#     mkdir busco_downloads
#     cd busco_downloads
#     if [ ! -L alveolata_odb10 ]
#     then
#         ln -s /home/genomics/workshop_material/genome_annotation/busco/alveolata_odb10 alveolata_odb10
#     fi
# fi
#
# # delete old output if existing
# if [ -d busco_braker3_babesia ]
# then
#     rm -r busco_braker3_babesia
# fi
#
# # run BUSCO
# busco -m proteins -i braker.aa -o busco_braker3_babesia \
#         -l alveolata_odb10 -c ${T} &> busco_braker3_babesia.log
#
# # Count number of transcripts by counting FASTA headers
# echo "Counting number of protein sequences = transcripts"
# grep -c ">" braker.aa
#
# # Number of genes, and descriptive statistics
# echo "Computing some descriptive statistics for BRAKER3:"
# analyze_exons.py -f braker.gtf

# %% [markdown]
# ## Task for group 3: Apply BRAKER2
#
# Use the following code cell to implement the application of BRAKER2, and execute BRAKER2. Use the genome file, the OrthoDB Metazoa file and the proteins.fa file mentioned, above. Apply `--skipOptimize`. Do not apply `--gm_max_intergenic 10000`. (Expected runtime: ~30 minutes.)

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with, takes ~30 minutes with 4 threads
#
# # delete output from a possible previous run if it exists
# if [ -d BRAKER2_babesia ]
# then
#     rm -rf BRAKER2_babesia
# fi
#
# ORTHODB=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa # adjust to suitable clade
#
# # run BRAKER2
# time braker.pl --workingdir=BRAKER2_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \
#     --prot_seq=${ORTHODB},/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa \
#     --AUGUSTUS_BIN_PATH=/usr/bin/ \
#     --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \
#     --skipOptimize
# Out:
# #**********************************************************************************
# #                               BRAKER CONFIGURATION
# #**********************************************************************************
# # BRAKER CALL: /opt/BRAKER/scripts/braker.pl --workingdir=BRAKER2_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa --prot_seq=/home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa,/home/genomics/workshop_material/genome_annotation/proteins/proteins.fa --AUGUSTUS_BIN_PATH=/usr/bin/ --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads 4 --skipOptimize
# # Sun May  7 12:57:20 2023: braker.pl version 3.0.3
# # Sun May  7 12:57:20 2023: Creating directory /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia.
# # Sun May  7 12:57:20 2023: Only Protein input detected, BRAKER will be executed in EP mode (BRAKER2).
# # Sun May  7 12:57:20 2023: Configuring of BRAKER for using external tools...
# # Sun May  7 12:57:20 2023: Trying to set $AUGUSTUS_CONFIG_PATH...
# # Sun May  7 12:57:20 2023: Found environment variable $AUGUSTUS_CONFIG_PATH.
# # Sun May  7 12:57:20 2023: Checking /usr/share/augustus/config/ as potential path for $AUGUSTUS_CONFIG_PATH.
# # Sun May  7 12:57:20 2023: Success! Setting $AUGUSTUS_CONFIG_PATH to /usr/share/augustus/config/!
# # Sun May  7 12:57:20 2023: WARNING: in file /opt/BRAKER/scripts/braker.pl at line 1894
# AUGUSTUS_CONFIG_PATH/species (in this case /usr/share/augustus/config//species) is not writeable. BRAKER will try to copy the AUGUSTUS config directory to a writeable location.
# # Sun May  7 12:57:20 2023: Log information is stored in file /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia/braker.log
# #*********
# # WARNING: Detected whitespace in fasta header of file /home/genomics/workshop_material/genome_annotation/orthodb/Alveolata.fa. This may later on cause problems! The pipeline will create a new file without spaces or "|" characters and a genome_header.map file to look up the old and new headers. This message will be suppressed from now on!
# #*********
# ProtHint Version 2.6.0
# Copyright 2019, Georgia Institute of Technology, USA
#
# Please cite
#   - ProtHint: https://doi.org/10.1093/nargab/lqaa026
#   - DIAMOND:  https://doi.org/10.1038/nmeth.3176
#   - Spaln:    https://doi.org/10.1093/bioinformatics/btn460
#
# Called from: /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia
# Cmd: /opt/ETP/bin/gmes/ProtHint/bin/prothint.py --threads=4 --geneMarkGtf /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia/GeneMark-ES/genemark.gtf /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia/genome.fa /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia/proteins.fa
#
# [Sun May  7 13:10:51 2023] Pre-processing protein input
# [Sun May  7 13:10:53 2023] Skipping GeneMark-ES, using the supplied gene seeds file instead
# [Sun May  7 13:10:53 2023] Translating gene seeds to proteins
# [Sun May  7 13:10:53 2023] Translation of seeds finished
# [Sun May  7 13:10:53 2023] Running DIAMOND
# diamond v0.9.24.125 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU GPL <https://www.gnu.org/licenses/gpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 4
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database file: /home/katharina/git/GenomeAnnotation_Workshop2023/BRAKER2_babesia/prot97t6h4_u
# Opening the database file...  [0.000196s]
# Loading sequences...  [2.57296s]
# Masking sequences...  [43.1602s]
# Writing sequences...  [0.784633s]
# Hashing sequences...  [0.181217s]
# Loading sequences...  [1.8e-05s]
# Writing trailer...  [0.0205s]
# Closing the input file...  [4.8e-05s]
# Closing the database file...  [3.7e-05s]
# Database hash = 7e0057f9092e0425b460e5a8eddfc1ba
# Processed 634660 sequences, 377385762 letters.
# Total time = 46.7201s
# diamond v0.9.24.125 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU GPL <https://www.gnu.org/licenses/gpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 4
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory:
# Opening the database...  [8e-05s]
# #Target sequences to report alignments for: 25
# Opening the input file...  [3.2e-05s]
# Opening the output file...  [5.4e-05s]
# Loading query sequences...  [0.002509s]
# Masking queries...  [0.040596s]
# Building query seed set...  [0.004109s]
# Algorithm: Double-indexed
# Building query histograms...  [0.003807s]
# Allocating buffers...  [4.3e-05s]
# Loading reference sequences...  [1.12289s]
# Building reference histograms...  [2.43081s]
# Allocating buffers...  [4.1e-05s]
# Initializing temporary storage...  [0.001323s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 0.
# Building reference index...  [5.11164s]
# Building query index...  [0.004241s]
# Building seed filter...  [0.352455s]
# Searching alignments...  [0.208455s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 1.
# Building reference index...  [5.5587s]
# Building query index...  [0.004306s]
# Building seed filter...  [0.350299s]
# Searching alignments...  [0.215071s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 2.
# Building reference index...  [5.83061s]
# Building query index...  [0.005285s]
# Building seed filter...  [0.364999s]
# Searching alignments...  [0.208392s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 3.
# Building reference index...  [4.87829s]
# Building query index...  [0.004342s]
# Building seed filter...  [0.370985s]
# Searching alignments...  [0.206437s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 0.
# Building reference index...  [4.91481s]
# Building query index...  [0.004426s]
# Building seed filter...  [0.372257s]
# Searching alignments...  [0.227429s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 1.
# Building reference index...  [5.52257s]
# Building query index...  [0.004652s]
# Building seed filter...  [0.335285s]
# Searching alignments...  [0.216847s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 2.
# Building reference index...  [5.74458s]
# Building query index...  [0.004772s]
# Building seed filter...  [0.366663s]
# Searching alignments...  [0.222241s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 3.
# Building reference index...  [4.85331s]
# Building query index...  [0.003822s]
# Building seed filter...  [0.340356s]
# Searching alignments...  [0.223758s]
# Deallocating buffers...  [0.083751s]
# Computing alignments...  [1.34568s]
# Deallocating reference...  [0.025631s]
# Loading reference sequences...  [2.8e-05s]
# Deallocating buffers...  [6e-06s]
# Deallocating queries...  [4.4e-05s]
# Loading query sequences...  [1.5e-05s]
# Closing the input file...  [1.8e-05s]
# Closing the output file...  [8.3e-05s]
# Closing the database file...  [1e-05s]
# Deallocating taxonomy...  [2e-06s]
# Total time = 52.0962s
# Reported 7835 pairwise alignments, 7835 HSPs.
# 370 queries aligned.
# [Sun May  7 13:12:32 2023] DIAMOND finished
# [Sun May  7 13:12:32 2023] Preparing pairs for alignments
# [Sun May  7 13:12:33 2023] Preparation of pairs finished
# [Sun May  7 13:12:33 2023] Starting spliced alignment with spaln
# [Sun May  7 13:12:33 2023] Loading alignment pairs into memory
# [Sun May  7 13:12:35 2023] Pairs loaded. Number of pairs to align: 7835
# [Sun May  7 13:12:35 2023] Starting the alignments
# [Sun May  7 13:12:35 2023] Enqueueing pair 0/7835 (0.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 8/7835 (0.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 16/7835 (0.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 24/7835 (0.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 32/7835 (0.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 40/7835 (0.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 48/7835 (0.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 55/7835 (0.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 63/7835 (0.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 71/7835 (0.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 79/7835 (1.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 87/7835 (1.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 95/7835 (1.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 102/7835 (1.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 110/7835 (1.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 118/7835 (1.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 126/7835 (1.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 134/7835 (1.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 142/7835 (1.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 149/7835 (1.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 157/7835 (2.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 165/7835 (2.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 173/7835 (2.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 181/7835 (2.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 189/7835 (2.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 196/7835 (2.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 204/7835 (2.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 212/7835 (2.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 220/7835 (2.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 228/7835 (2.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 236/7835 (3.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 243/7835 (3.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 251/7835 (3.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 259/7835 (3.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 267/7835 (3.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 275/7835 (3.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 283/7835 (3.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 290/7835 (3.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 298/7835 (3.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 306/7835 (3.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 314/7835 (4.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 322/7835 (4.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 330/7835 (4.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 337/7835 (4.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 345/7835 (4.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 353/7835 (4.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 361/7835 (4.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 369/7835 (4.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 377/7835 (4.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 384/7835 (4.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 392/7835 (5.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 400/7835 (5.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 408/7835 (5.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 416/7835 (5.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 424/7835 (5.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 431/7835 (5.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 439/7835 (5.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 447/7835 (5.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 455/7835 (5.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 463/7835 (5.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 471/7835 (6.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 478/7835 (6.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 486/7835 (6.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 494/7835 (6.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 502/7835 (6.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 510/7835 (6.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 518/7835 (6.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 525/7835 (6.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 533/7835 (6.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 541/7835 (6.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 549/7835 (7.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 557/7835 (7.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 565/7835 (7.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 572/7835 (7.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 580/7835 (7.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 588/7835 (7.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 596/7835 (7.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 604/7835 (7.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 612/7835 (7.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 619/7835 (7.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 627/7835 (8.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 635/7835 (8.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 643/7835 (8.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 651/7835 (8.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 659/7835 (8.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 666/7835 (8.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 674/7835 (8.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 682/7835 (8.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 690/7835 (8.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 698/7835 (8.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 706/7835 (9.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 713/7835 (9.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 721/7835 (9.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 729/7835 (9.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 737/7835 (9.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 745/7835 (9.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 753/7835 (9.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 760/7835 (9.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 768/7835 (9.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 776/7835 (9.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 784/7835 (10.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 792/7835 (10.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 800/7835 (10.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 808/7835 (10.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 815/7835 (10.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 823/7835 (10.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 831/7835 (10.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 839/7835 (10.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 847/7835 (10.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 855/7835 (10.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 862/7835 (11.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 870/7835 (11.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 878/7835 (11.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 886/7835 (11.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 894/7835 (11.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 902/7835 (11.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 909/7835 (11.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 917/7835 (11.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 925/7835 (11.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 933/7835 (11.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 941/7835 (12.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 949/7835 (12.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 956/7835 (12.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 964/7835 (12.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 972/7835 (12.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 980/7835 (12.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 988/7835 (12.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 996/7835 (12.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1003/7835 (12.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1011/7835 (12.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1019/7835 (13.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1027/7835 (13.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1035/7835 (13.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1043/7835 (13.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1050/7835 (13.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1058/7835 (13.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1066/7835 (13.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1074/7835 (13.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1082/7835 (13.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1090/7835 (13.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1097/7835 (14.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1105/7835 (14.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1113/7835 (14.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1121/7835 (14.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1129/7835 (14.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1137/7835 (14.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1144/7835 (14.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1152/7835 (14.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1160/7835 (14.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1168/7835 (14.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1176/7835 (15.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1184/7835 (15.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1191/7835 (15.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1199/7835 (15.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1207/7835 (15.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1215/7835 (15.5%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1223/7835 (15.6%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1231/7835 (15.7%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1238/7835 (15.8%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1246/7835 (15.9%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1254/7835 (16.0%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1262/7835 (16.1%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1270/7835 (16.2%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1278/7835 (16.3%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1285/7835 (16.4%)
# [Sun May  7 13:12:35 2023] Enqueueing pair 1293/7835 (16.5%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1301/7835 (16.6%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1309/7835 (16.7%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1317/7835 (16.8%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1325/7835 (16.9%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1332/7835 (17.0%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1340/7835 (17.1%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1348/7835 (17.2%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1356/7835 (17.3%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1364/7835 (17.4%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1372/7835 (17.5%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1379/7835 (17.6%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1387/7835 (17.7%)
# [Sun May  7 13:12:46 2023] Enqueueing pair 1395/7835 (17.8%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1403/7835 (17.9%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1411/7835 (18.0%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1419/7835 (18.1%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1426/7835 (18.2%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1434/7835 (18.3%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1442/7835 (18.4%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1450/7835 (18.5%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1458/7835 (18.6%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1466/7835 (18.7%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1473/7835 (18.8%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1481/7835 (18.9%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1489/7835 (19.0%)
# [Sun May  7 13:12:47 2023] Enqueueing pair 1497/7835 (19.1%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1505/7835 (19.2%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1513/7835 (19.3%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1520/7835 (19.4%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1528/7835 (19.5%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1536/7835 (19.6%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1544/7835 (19.7%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1552/7835 (19.8%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1560/7835 (19.9%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1567/7835 (20.0%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1575/7835 (20.1%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1583/7835 (20.2%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1591/7835 (20.3%)
# [Sun May  7 13:12:52 2023] Enqueueing pair 1599/7835 (20.4%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1607/7835 (20.5%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1615/7835 (20.6%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1622/7835 (20.7%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1630/7835 (20.8%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1638/7835 (20.9%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1646/7835 (21.0%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1654/7835 (21.1%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1662/7835 (21.2%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1669/7835 (21.3%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1677/7835 (21.4%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1685/7835 (21.5%)
# [Sun May  7 13:12:58 2023] Enqueueing pair 1693/7835 (21.6%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1701/7835 (21.7%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1709/7835 (21.8%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1716/7835 (21.9%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1724/7835 (22.0%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1732/7835 (22.1%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1740/7835 (22.2%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1748/7835 (22.3%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1756/7835 (22.4%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1763/7835 (22.5%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1771/7835 (22.6%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1779/7835 (22.7%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1787/7835 (22.8%)
# [Sun May  7 13:13:04 2023] Enqueueing pair 1795/7835 (22.9%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1803/7835 (23.0%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1810/7835 (23.1%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1818/7835 (23.2%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1826/7835 (23.3%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1834/7835 (23.4%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1842/7835 (23.5%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1850/7835 (23.6%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1857/7835 (23.7%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1865/7835 (23.8%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1873/7835 (23.9%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1881/7835 (24.0%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1889/7835 (24.1%)
# [Sun May  7 13:13:05 2023] Enqueueing pair 1897/7835 (24.2%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1904/7835 (24.3%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1912/7835 (24.4%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1920/7835 (24.5%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1928/7835 (24.6%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1936/7835 (24.7%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1944/7835 (24.8%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1951/7835 (24.9%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1959/7835 (25.0%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1967/7835 (25.1%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1975/7835 (25.2%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1983/7835 (25.3%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1991/7835 (25.4%)
# [Sun May  7 13:13:06 2023] Enqueueing pair 1998/7835 (25.5%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2006/7835 (25.6%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2014/7835 (25.7%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2022/7835 (25.8%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2030/7835 (25.9%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2038/7835 (26.0%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2045/7835 (26.1%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2053/7835 (26.2%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2061/7835 (26.3%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2069/7835 (26.4%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2077/7835 (26.5%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2085/7835 (26.6%)
# [Sun May  7 13:13:12 2023] Enqueueing pair 2092/7835 (26.7%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2100/7835 (26.8%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2108/7835 (26.9%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2116/7835 (27.0%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2124/7835 (27.1%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2132/7835 (27.2%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2139/7835 (27.3%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2147/7835 (27.4%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2155/7835 (27.5%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2163/7835 (27.6%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2171/7835 (27.7%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2179/7835 (27.8%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2186/7835 (27.9%)
# [Sun May  7 13:13:19 2023] Enqueueing pair 2194/7835 (28.0%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2202/7835 (28.1%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2210/7835 (28.2%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2218/7835 (28.3%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2226/7835 (28.4%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2233/7835 (28.5%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2241/7835 (28.6%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2249/7835 (28.7%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2257/7835 (28.8%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2265/7835 (28.9%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2273/7835 (29.0%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2280/7835 (29.1%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2288/7835 (29.2%)
# [Sun May  7 13:13:23 2023] Enqueueing pair 2296/7835 (29.3%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2304/7835 (29.4%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2312/7835 (29.5%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2320/7835 (29.6%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2327/7835 (29.7%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2335/7835 (29.8%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2343/7835 (29.9%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2351/7835 (30.0%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2359/7835 (30.1%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2367/7835 (30.2%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2375/7835 (30.3%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2382/7835 (30.4%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2390/7835 (30.5%)
# [Sun May  7 13:13:27 2023] Enqueueing pair 2398/7835 (30.6%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2406/7835 (30.7%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2414/7835 (30.8%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2422/7835 (30.9%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2429/7835 (31.0%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2437/7835 (31.1%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2445/7835 (31.2%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2453/7835 (31.3%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2461/7835 (31.4%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2469/7835 (31.5%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2476/7835 (31.6%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2484/7835 (31.7%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2492/7835 (31.8%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2500/7835 (31.9%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2508/7835 (32.0%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2516/7835 (32.1%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2523/7835 (32.2%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2531/7835 (32.3%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2539/7835 (32.4%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2547/7835 (32.5%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2555/7835 (32.6%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2563/7835 (32.7%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2570/7835 (32.8%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2578/7835 (32.9%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2586/7835 (33.0%)
# [Sun May  7 13:13:31 2023] Enqueueing pair 2594/7835 (33.1%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2602/7835 (33.2%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2610/7835 (33.3%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2617/7835 (33.4%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2625/7835 (33.5%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2633/7835 (33.6%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2641/7835 (33.7%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2649/7835 (33.8%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2657/7835 (33.9%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2664/7835 (34.0%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2672/7835 (34.1%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2680/7835 (34.2%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2688/7835 (34.3%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2696/7835 (34.4%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2704/7835 (34.5%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2711/7835 (34.6%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2719/7835 (34.7%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2727/7835 (34.8%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2735/7835 (34.9%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2743/7835 (35.0%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2751/7835 (35.1%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2758/7835 (35.2%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2766/7835 (35.3%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2774/7835 (35.4%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2782/7835 (35.5%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2790/7835 (35.6%)
# [Sun May  7 13:13:41 2023] Enqueueing pair 2798/7835 (35.7%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2805/7835 (35.8%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2813/7835 (35.9%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2821/7835 (36.0%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2829/7835 (36.1%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2837/7835 (36.2%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2845/7835 (36.3%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2852/7835 (36.4%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2860/7835 (36.5%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2868/7835 (36.6%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2876/7835 (36.7%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2884/7835 (36.8%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2892/7835 (36.9%)
# [Sun May  7 13:13:47 2023] Enqueueing pair 2899/7835 (37.0%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2907/7835 (37.1%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2915/7835 (37.2%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2923/7835 (37.3%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2931/7835 (37.4%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2939/7835 (37.5%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2946/7835 (37.6%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2954/7835 (37.7%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2962/7835 (37.8%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2970/7835 (37.9%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2978/7835 (38.0%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2986/7835 (38.1%)
# [Sun May  7 13:13:51 2023] Enqueueing pair 2993/7835 (38.2%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3001/7835 (38.3%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3009/7835 (38.4%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3017/7835 (38.5%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3025/7835 (38.6%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3033/7835 (38.7%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3040/7835 (38.8%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3048/7835 (38.9%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3056/7835 (39.0%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3064/7835 (39.1%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3072/7835 (39.2%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3080/7835 (39.3%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3087/7835 (39.4%)
# [Sun May  7 13:13:53 2023] Enqueueing pair 3095/7835 (39.5%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3103/7835 (39.6%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3111/7835 (39.7%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3119/7835 (39.8%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3127/7835 (39.9%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3134/7835 (40.0%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3142/7835 (40.1%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3150/7835 (40.2%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3158/7835 (40.3%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3166/7835 (40.4%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3174/7835 (40.5%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3182/7835 (40.6%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3189/7835 (40.7%)
# [Sun May  7 13:13:57 2023] Enqueueing pair 3197/7835 (40.8%)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3205/7835 (40.9%). Est. time left: 00:02:09 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3213/7835 (41.0%). Est. time left: 00:02:09 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3221/7835 (41.1%). Est. time left: 00:02:08 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3229/7835 (41.2%). Est. time left: 00:02:08 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3236/7835 (41.3%). Est. time left: 00:02:07 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3244/7835 (41.4%). Est. time left: 00:02:06 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3252/7835 (41.5%). Est. time left: 00:02:06 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3260/7835 (41.6%). Est. time left: 00:02:05 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3268/7835 (41.7%). Est. time left: 00:02:05 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3276/7835 (41.8%). Est. time left: 00:02:04 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3283/7835 (41.9%). Est. time left: 00:02:04 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3291/7835 (42.0%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:04 2023] Enqueueing pair 3299/7835 (42.1%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3307/7835 (42.2%). Est. time left: 00:02:05 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3315/7835 (42.3%). Est. time left: 00:02:05 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3323/7835 (42.4%). Est. time left: 00:02:04 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3330/7835 (42.5%). Est. time left: 00:02:04 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3338/7835 (42.6%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3346/7835 (42.7%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3354/7835 (42.8%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3362/7835 (42.9%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3370/7835 (43.0%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3377/7835 (43.1%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3385/7835 (43.2%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:06 2023] Enqueueing pair 3393/7835 (43.3%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3401/7835 (43.4%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3409/7835 (43.5%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3417/7835 (43.6%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3424/7835 (43.7%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3432/7835 (43.8%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3440/7835 (43.9%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3448/7835 (44.0%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3456/7835 (44.1%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3464/7835 (44.2%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3471/7835 (44.3%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3479/7835 (44.4%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3487/7835 (44.5%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:09 2023] Enqueueing pair 3495/7835 (44.6%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3503/7835 (44.7%). Est. time left: 00:02:03 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3511/7835 (44.8%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3518/7835 (44.9%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3526/7835 (45.0%). Est. time left: 00:02:02 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3534/7835 (45.1%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3542/7835 (45.2%). Est. time left: 00:02:01 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3550/7835 (45.3%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3558/7835 (45.4%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3565/7835 (45.5%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3573/7835 (45.6%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3581/7835 (45.7%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3589/7835 (45.8%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:14 2023] Enqueueing pair 3597/7835 (45.9%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3605/7835 (46.0%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3612/7835 (46.1%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3620/7835 (46.2%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3628/7835 (46.3%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3636/7835 (46.4%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3644/7835 (46.5%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3652/7835 (46.6%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3659/7835 (46.7%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3667/7835 (46.8%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3675/7835 (46.9%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3683/7835 (47.0%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3691/7835 (47.1%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:16 2023] Enqueueing pair 3699/7835 (47.2%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3706/7835 (47.3%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3714/7835 (47.4%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3722/7835 (47.5%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3730/7835 (47.6%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3738/7835 (47.7%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3746/7835 (47.8%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3753/7835 (47.9%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3761/7835 (48.0%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3769/7835 (48.1%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3777/7835 (48.2%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3785/7835 (48.3%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3793/7835 (48.4%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3800/7835 (48.5%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3808/7835 (48.6%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3816/7835 (48.7%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3824/7835 (48.8%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3832/7835 (48.9%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3840/7835 (49.0%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3847/7835 (49.1%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3855/7835 (49.2%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3863/7835 (49.3%). Est. time left: 00:01:48 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3871/7835 (49.4%). Est. time left: 00:01:48 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3879/7835 (49.5%). Est. time left: 00:01:48 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3887/7835 (49.6%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:20 2023] Enqueueing pair 3894/7835 (49.7%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3902/7835 (49.8%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3910/7835 (49.9%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3918/7835 (50.0%). Est. time left: 00:02:00 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3926/7835 (50.1%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3934/7835 (50.2%). Est. time left: 00:01:59 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3942/7835 (50.3%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3949/7835 (50.4%). Est. time left: 00:01:58 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3957/7835 (50.5%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3965/7835 (50.6%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3973/7835 (50.7%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3981/7835 (50.8%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3989/7835 (50.9%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 3996/7835 (51.0%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4004/7835 (51.1%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4012/7835 (51.2%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4020/7835 (51.3%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4028/7835 (51.4%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4036/7835 (51.5%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4043/7835 (51.6%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4051/7835 (51.7%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4059/7835 (51.8%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4067/7835 (51.9%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4075/7835 (52.0%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4083/7835 (52.1%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4090/7835 (52.2%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:34 2023] Enqueueing pair 4098/7835 (52.3%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4106/7835 (52.4%). Est. time left: 00:01:57 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4114/7835 (52.5%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4122/7835 (52.6%). Est. time left: 00:01:56 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4130/7835 (52.7%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4137/7835 (52.8%). Est. time left: 00:01:55 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4145/7835 (52.9%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4153/7835 (53.0%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4161/7835 (53.1%). Est. time left: 00:01:54 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4169/7835 (53.2%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4177/7835 (53.3%). Est. time left: 00:01:53 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4184/7835 (53.4%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:43 2023] Enqueueing pair 4192/7835 (53.5%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4200/7835 (53.6%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4208/7835 (53.7%). Est. time left: 00:01:52 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4216/7835 (53.8%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4224/7835 (53.9%). Est. time left: 00:01:51 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4231/7835 (54.0%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4239/7835 (54.1%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4247/7835 (54.2%). Est. time left: 00:01:50 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4255/7835 (54.3%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4263/7835 (54.4%). Est. time left: 00:01:49 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4271/7835 (54.5%). Est. time left: 00:01:48 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4278/7835 (54.6%). Est. time left: 00:01:48 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4286/7835 (54.7%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:44 2023] Enqueueing pair 4294/7835 (54.8%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4302/7835 (54.9%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4310/7835 (55.0%). Est. time left: 00:01:47 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4318/7835 (55.1%). Est. time left: 00:01:46 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4325/7835 (55.2%). Est. time left: 00:01:46 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4333/7835 (55.3%). Est. time left: 00:01:46 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4341/7835 (55.4%). Est. time left: 00:01:45 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4349/7835 (55.5%). Est. time left: 00:01:45 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4357/7835 (55.6%). Est. time left: 00:01:44 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4365/7835 (55.7%). Est. time left: 00:01:44 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4372/7835 (55.8%). Est. time left: 00:01:43 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4380/7835 (55.9%). Est. time left: 00:01:43 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4388/7835 (56.0%). Est. time left: 00:01:43 (hh:mm:ss)
# [Sun May  7 13:14:45 2023] Enqueueing pair 4396/7835 (56.1%). Est. time left: 00:01:42 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4404/7835 (56.2%). Est. time left: 00:01:43 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4412/7835 (56.3%). Est. time left: 00:01:42 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4419/7835 (56.4%). Est. time left: 00:01:42 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4427/7835 (56.5%). Est. time left: 00:01:41 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4435/7835 (56.6%). Est. time left: 00:01:41 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4443/7835 (56.7%). Est. time left: 00:01:41 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4451/7835 (56.8%). Est. time left: 00:01:40 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4459/7835 (56.9%). Est. time left: 00:01:40 (hh:mm:ss)
# [Sun May  7 13:14:46 2023] Enqueueing pair 4466/7835 (57.0%). Est. time left: 00:01:39 (hh:mm:ss)
# ...
# [Sun May  7 13:16:14 2023] Enqueueing pair 6613/7835 (84.4%). Est. time left: 00:00:41 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6621/7835 (84.5%). Est. time left: 00:00:41 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6629/7835 (84.6%). Est. time left: 00:00:40 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6637/7835 (84.7%). Est. time left: 00:00:40 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6645/7835 (84.8%). Est. time left: 00:00:40 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6652/7835 (84.9%). Est. time left: 00:00:39 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6660/7835 (85.0%). Est. time left: 00:00:39 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6668/7835 (85.1%). Est. time left: 00:00:39 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6676/7835 (85.2%). Est. time left: 00:00:39 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6684/7835 (85.3%). Est. time left: 00:00:38 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6692/7835 (85.4%). Est. time left: 00:00:38 (hh:mm:ss)
# [Sun May  7 13:16:14 2023] Enqueueing pair 6699/7835 (85.5%). Est. time left: 00:00:38 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6707/7835 (85.6%). Est. time left: 00:00:38 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6715/7835 (85.7%). Est. time left: 00:00:37 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6723/7835 (85.8%). Est. time left: 00:00:37 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6731/7835 (85.9%). Est. time left: 00:00:37 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6739/7835 (86.0%). Est. time left: 00:00:36 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6746/7835 (86.1%). Est. time left: 00:00:36 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6754/7835 (86.2%). Est. time left: 00:00:36 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6762/7835 (86.3%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6770/7835 (86.4%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6778/7835 (86.5%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6786/7835 (86.6%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:15 2023] Enqueueing pair 6793/7835 (86.7%). Est. time left: 00:00:34 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6801/7835 (86.8%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6809/7835 (86.9%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6817/7835 (87.0%). Est. time left: 00:00:35 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6825/7835 (87.1%). Est. time left: 00:00:34 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6833/7835 (87.2%). Est. time left: 00:00:34 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6840/7835 (87.3%). Est. time left: 00:00:34 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6848/7835 (87.4%). Est. time left: 00:00:34 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6856/7835 (87.5%). Est. time left: 00:00:33 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6864/7835 (87.6%). Est. time left: 00:00:33 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6872/7835 (87.7%). Est. time left: 00:00:33 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6880/7835 (87.8%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6887/7835 (87.9%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:24 2023] Enqueueing pair 6895/7835 (88.0%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6903/7835 (88.1%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6911/7835 (88.2%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6919/7835 (88.3%). Est. time left: 00:00:32 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6927/7835 (88.4%). Est. time left: 00:00:31 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6934/7835 (88.5%). Est. time left: 00:00:31 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6942/7835 (88.6%). Est. time left: 00:00:31 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6950/7835 (88.7%). Est. time left: 00:00:30 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6958/7835 (88.8%). Est. time left: 00:00:30 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6966/7835 (88.9%). Est. time left: 00:00:30 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6974/7835 (89.0%). Est. time left: 00:00:29 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6981/7835 (89.1%). Est. time left: 00:00:29 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6989/7835 (89.2%). Est. time left: 00:00:29 (hh:mm:ss)
# [Sun May  7 13:16:29 2023] Enqueueing pair 6997/7835 (89.3%). Est. time left: 00:00:29 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7005/7835 (89.4%). Est. time left: 00:00:29 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7013/7835 (89.5%). Est. time left: 00:00:28 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7021/7835 (89.6%). Est. time left: 00:00:28 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7028/7835 (89.7%). Est. time left: 00:00:28 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7036/7835 (89.8%). Est. time left: 00:00:27 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7044/7835 (89.9%). Est. time left: 00:00:27 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7052/7835 (90.0%). Est. time left: 00:00:27 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7060/7835 (90.1%). Est. time left: 00:00:27 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7068/7835 (90.2%). Est. time left: 00:00:26 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7076/7835 (90.3%). Est. time left: 00:00:26 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7083/7835 (90.4%). Est. time left: 00:00:26 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7091/7835 (90.5%). Est. time left: 00:00:25 (hh:mm:ss)
# [Sun May  7 13:16:32 2023] Enqueueing pair 7099/7835 (90.6%). Est. time left: 00:00:25 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7107/7835 (90.7%). Est. time left: 00:00:25 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7115/7835 (90.8%). Est. time left: 00:00:25 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7123/7835 (90.9%). Est. time left: 00:00:25 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7130/7835 (91.0%). Est. time left: 00:00:24 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7138/7835 (91.1%). Est. time left: 00:00:24 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7146/7835 (91.2%). Est. time left: 00:00:24 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7154/7835 (91.3%). Est. time left: 00:00:23 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7162/7835 (91.4%). Est. time left: 00:00:23 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7170/7835 (91.5%). Est. time left: 00:00:23 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7177/7835 (91.6%). Est. time left: 00:00:23 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7185/7835 (91.7%). Est. time left: 00:00:22 (hh:mm:ss)
# [Sun May  7 13:16:35 2023] Enqueueing pair 7193/7835 (91.8%). Est. time left: 00:00:22 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7201/7835 (91.9%). Est. time left: 00:00:23 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7209/7835 (92.0%). Est. time left: 00:00:22 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7217/7835 (92.1%). Est. time left: 00:00:22 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7224/7835 (92.2%). Est. time left: 00:00:22 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7232/7835 (92.3%). Est. time left: 00:00:21 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7240/7835 (92.4%). Est. time left: 00:00:21 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7248/7835 (92.5%). Est. time left: 00:00:21 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7256/7835 (92.6%). Est. time left: 00:00:20 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7264/7835 (92.7%). Est. time left: 00:00:20 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7271/7835 (92.8%). Est. time left: 00:00:20 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7279/7835 (92.9%). Est. time left: 00:00:20 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7287/7835 (93.0%). Est. time left: 00:00:19 (hh:mm:ss)
# [Sun May  7 13:16:45 2023] Enqueueing pair 7295/7835 (93.1%). Est. time left: 00:00:19 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7303/7835 (93.2%). Est. time left: 00:00:19 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7311/7835 (93.3%). Est. time left: 00:00:19 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7318/7835 (93.4%). Est. time left: 00:00:18 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7326/7835 (93.5%). Est. time left: 00:00:18 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7334/7835 (93.6%). Est. time left: 00:00:18 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7342/7835 (93.7%). Est. time left: 00:00:17 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7350/7835 (93.8%). Est. time left: 00:00:17 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7358/7835 (93.9%). Est. time left: 00:00:17 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7365/7835 (94.0%). Est. time left: 00:00:17 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7373/7835 (94.1%). Est. time left: 00:00:16 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7381/7835 (94.2%). Est. time left: 00:00:16 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7389/7835 (94.3%). Est. time left: 00:00:16 (hh:mm:ss)
# [Sun May  7 13:16:47 2023] Enqueueing pair 7397/7835 (94.4%). Est. time left: 00:00:15 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7405/7835 (94.5%). Est. time left: 00:00:15 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7412/7835 (94.6%). Est. time left: 00:00:15 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7420/7835 (94.7%). Est. time left: 00:00:15 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7428/7835 (94.8%). Est. time left: 00:00:14 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7436/7835 (94.9%). Est. time left: 00:00:14 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7444/7835 (95.0%). Est. time left: 00:00:14 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7452/7835 (95.1%). Est. time left: 00:00:14 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7459/7835 (95.2%). Est. time left: 00:00:13 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7467/7835 (95.3%). Est. time left: 00:00:13 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7475/7835 (95.4%). Est. time left: 00:00:13 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7483/7835 (95.5%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7491/7835 (95.6%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:16:49 2023] Enqueueing pair 7499/7835 (95.7%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7506/7835 (95.8%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7514/7835 (95.9%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7522/7835 (96.0%). Est. time left: 00:00:12 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7530/7835 (96.1%). Est. time left: 00:00:11 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7538/7835 (96.2%). Est. time left: 00:00:11 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7546/7835 (96.3%). Est. time left: 00:00:11 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7553/7835 (96.4%). Est. time left: 00:00:10 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7561/7835 (96.5%). Est. time left: 00:00:10 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7569/7835 (96.6%). Est. time left: 00:00:10 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7577/7835 (96.7%). Est. time left: 00:00:10 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7585/7835 (96.8%). Est. time left: 00:00:09 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7593/7835 (96.9%). Est. time left: 00:00:09 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7600/7835 (97.0%). Est. time left: 00:00:09 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7608/7835 (97.1%). Est. time left: 00:00:08 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7616/7835 (97.2%). Est. time left: 00:00:08 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7624/7835 (97.3%). Est. time left: 00:00:08 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7632/7835 (97.4%). Est. time left: 00:00:08 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7640/7835 (97.5%). Est. time left: 00:00:07 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7647/7835 (97.6%). Est. time left: 00:00:07 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7655/7835 (97.7%). Est. time left: 00:00:07 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7663/7835 (97.8%). Est. time left: 00:00:06 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7671/7835 (97.9%). Est. time left: 00:00:06 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7679/7835 (98.0%). Est. time left: 00:00:06 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7687/7835 (98.1%). Est. time left: 00:00:06 (hh:mm:ss)
# [Sun May  7 13:17:01 2023] Enqueueing pair 7694/7835 (98.2%). Est. time left: 00:00:05 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7702/7835 (98.3%). Est. time left: 00:00:05 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7710/7835 (98.4%). Est. time left: 00:00:05 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7718/7835 (98.5%). Est. time left: 00:00:05 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7726/7835 (98.6%). Est. time left: 00:00:04 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7734/7835 (98.7%). Est. time left: 00:00:04 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7741/7835 (98.8%). Est. time left: 00:00:04 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7749/7835 (98.9%). Est. time left: 00:00:04 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7757/7835 (99.0%). Est. time left: 00:00:03 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7765/7835 (99.1%). Est. time left: 00:00:03 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7773/7835 (99.2%). Est. time left: 00:00:03 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7781/7835 (99.3%). Est. time left: 00:00:02 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7788/7835 (99.4%). Est. time left: 00:00:02 (hh:mm:ss)
# [Sun May  7 13:17:07 2023] Enqueueing pair 7796/7835 (99.5%). Est. time left: 00:00:02 (hh:mm:ss)
# [Sun May  7 13:17:18 2023] Enqueueing pair 7804/7835 (99.6%). Est. time left: 00:00:02 (hh:mm:ss)
# [Sun May  7 13:17:18 2023] Enqueueing pair 7812/7835 (99.7%). Est. time left: 00:00:01 (hh:mm:ss)
# [Sun May  7 13:17:18 2023] Enqueueing pair 7820/7835 (99.8%). Est. time left: 00:00:01 (hh:mm:ss)
# [Sun May  7 13:17:18 2023] Enqueueing pair 7828/7835 (99.9%). Est. time left: 00:00:01 (hh:mm:ss)
# [Sun May  7 13:18:12 2023] 7835/7835 (100%) pairs aligned
# [Sun May  7 13:18:12 2023] Alignment of pairs finished
# [Sun May  7 13:18:12 2023] Translating coordinates from local pair level to contig level
# [Sun May  7 13:18:13 2023] Finished spliced alignment
# [Sun May  7 13:18:13 2023] Flagging top chains
# [Sun May  7 13:18:13 2023] Processing the output
# [Sun May  7 13:18:15 2023] Output processed
# [Sun May  7 13:18:15 2023] ProtHint finished.
# #*********
# # WARNING:
# # The hints file(s) for GeneMark-EX contain less than 1000 introns. (In total, 887 unique introns are contained.)
# # Genemark-EX might fail due to the low number of hints.
# #*********

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with
#
# source conda_init
# conda activate busco_env
#
# cd BRAKER2_babesia
# # create links if not already present
# if [ ! -d busco_downloads ]
# then
#     mkdir busco_downloads
#     cd busco_downloads
#     if [ ! -L alveolata_odb10 ]
#     then
#         ln -s /home/genomics/workshop_material/genome_annotation/busco/alveolata_odb10 alveolata_odb10
#     fi
# fi
#
# # delete old output if existing
# if [ -d busco_braker2_babesia ]
# then
#     rm -r busco_braker2_babesia
# fi
#
# # run BUSCO
# busco -m proteins -i braker.aa -o busco_braker2_babesia \
#         -l alveolata_odb10 -c ${T} &> busco_braker2_babesia.log
#
# # Count number of transcripts by counting FASTA headers
# echo "Counting number of protein sequences = transcripts"
# grep -c ">" braker.aa
#
# # Number of genes, and descriptive statistics
# echo "Computing some descriptive statistics for GALBA:"
# analyze_exons.py -f braker.gtf

# %% [markdown]
# ## Task for group 4: Apply BRAKER1
#
# Use the following code cell to implement the application of BRAKER1, and execute BRAKER1. Use the genome file and the Merged.bam file mentioned, above. Apply `--skipOptimize`. Do not apply `--gm_max_intergenic 10000`. (Expected runtime: ~10 minutes.)

# %%
# %%script bash
#
# T=4 # adjust to number of threads that you booted with, takes ~30 minutes with 4 threads
#
# # delete output from a possible previous run if it exists
# if [ -d BRAKER1_babesia ]
# then
#     rm -rf BRAKER1_babesia
# fi
#
# # run BRAKER1
# time braker.pl --workingdir=BRAKER1_babesia --genome=/home/genomics/workshop_material/genome_annotation/genome/genome.fa \
#     --bam=/home/genomics/workshop_material/genome_annotation/sra/SRR19666444.s.bam \
#     --AUGUSTUS_BIN_PATH=/usr/bin/ \
#     --AUGUSTUS_SCRIPTS_PATH=/usr/share/augustus/scripts/ --threads ${T} \
#     --skipOptimize

# %% [markdown]
# ## Do we have a sensivity problem?
#
# When comparing the obtained BUSCO scores, you may wonder why we are missing BUSCOs that were detected on genome level. One possible reason is that MetaEuk, the gene finder employed to detect BUSCOs on genome level, is not always ensuring the validity of a gene structure. Another reason, particularly in BRAKER, may be the lack of evidence, and poor training (remember, we are using only a small proportion of a small genomes, and we skipped an optimization step for AUGUSTUS training). If you have time left, you may play with TSEBRA to generate a possibly superior gene set. Consider combining the gene sets of BRAKER1 and BRAKER2, or even of BRAKER1, BRAKER2, and BRAKER3. Keep in mind that we learned how to enforce a gene set even in lack of evidence.

# %%
<details>
  <summary><b>Out of time but want to see results? Click here!</b></summary>

</details>
